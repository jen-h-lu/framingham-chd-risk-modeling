# %%
import pandas as pd

df = pd.read_csv("../data/framingham.csv")
df.head()
df.shape
# Out:
# (4240, 16)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="TenYearCHD", data=df)
plt.title("10-Year Coronary Heart Disease Outcome Distribution")
plt.show()
